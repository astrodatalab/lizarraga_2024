# %%
#Some images have been excluded due to too much noise/no appparent features that can be extracted

from IPython.display import display
import pandas as pd

# Path to the CSV file
csv_path = './results.csv'

# Load the CSV file into a DataFrame
results_df = pd.read_csv(csv_path)

# Filter the DataFrame to only include rows where the 'Image File' column starts with 'epoch_15'
filtered_df = results_df[results_df['Image File'].str.startswith('epoch_15')]

# Display the filtered DataFrame
print("Filtered DataFrame:")
display(filtered_df)

# Calculate the average of each numeric column
column_averages = filtered_df.mean(numeric_only=True)

# Print the average for each column
print("\nAverages for each numeric column:")
for column, avg in column_averages.items():
    print(f"{column}: {avg}")
# Out:
# Filtered DataFrame:
#       Semi-major Axis  Semi-minor Axis  Ellipticity  Orientation Angle  \
# 3            1.755813         1.340133     0.236745           1.121417
# 4            1.499771         1.107257     0.261716           0.708402
# 5            1.972750         1.585459     0.196321          -1.402329
# 6            2.617980         1.701302     0.350147           0.353714
# 7            1.690844         1.331421     0.212570           1.236556
# ...               ...              ...          ...                ...
# 4614         5.105482         2.986325     0.415075           0.481275
# 4615         2.771508         2.235505     0.193397          -0.103195
# 4616         3.194469         2.581301     0.191947           1.259068
# 4617         2.447732         1.482015     0.394536          -0.574085
# 4618         2.684504         2.439787     0.091159           0.188418
#
#       Isophotal Area  Sersic Index              Image File
# ...
