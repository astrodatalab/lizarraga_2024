# %%
from IPython.display import display
import pandas as pd

# Path to the CSV file
csv_path = './testing_metrics.csv'

# Load the CSV file into a DataFrame
results_df = pd.read_csv(csv_path)

# Display the DataFrame
display(results_df)

# Calculate the average of each numeric column, excluding 'Sequential Index' and 'Object ID'
column_averages = results_df.drop(columns=['Sequential Index', 'Object ID']).mean(numeric_only=True)

# Print the average for each column
print("\nAverages for each numeric column (excluding 'Sequential Index' and 'Object ID'):")
for column, avg in column_averages.items():
    print(f"{column}: {avg}")
# Out:
#        Sequential Index          Object ID  Orientation Angle  \
# 0                     0  36407063378678903              45.31
# 1                     1  36407187932710008             -49.18
# 2                     2  36407187932722372              30.40
# 3                     3  36407187932722754              53.20
# 4                     4  36407187932723360              20.62
# ...                 ...                ...                ...
# 40909             40909  74649164419438448              10.98
# 40910             40910  74649164419461709               2.47
# 40911             40911  74649164419466121              26.11
# 40912             40912  74649168714403940             -12.47
# 40913             40913  74649168714406416             -57.72
#
#        Semi-major Axis  Semi-minor Axis  Isophotal Area  Sersic Index  \
# 0                5.245            4.475           603.0         2.306
# 1                2.356            2.050            93.0         1.573
# ...
