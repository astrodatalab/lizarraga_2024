# %%
from IPython.display import display
import pandas as pd

csv_path = './AndrewMetrics.csv'

results_df = pd.read_csv(csv_path)

display(results_df)

column_averages = results_df.drop(columns=['Image Index']).mean(numeric_only=True)

print("\nAverages for each numeric column (excluding 'Image Index'):")
for column, avg in column_averages.items():
    print(f"{column}: {avg}")
# Out:
#        Semi-major Axis  Semi-minor Axis  Ellipticity  Orientation Angle  \
# 0             2.042630         1.194813     0.415061          -0.934689
# 1             1.488052         0.652920     0.561225           0.601398
# 2             7.500580         6.917913     0.077683          -0.869827
# 3             1.836931         0.614250     0.665611           1.451994
# 4             3.592643         2.487505     0.307611           0.010001
# ...                ...              ...          ...                ...
# 39003         1.130800         0.890493     0.212510          -1.154887
# 39004         3.122172         1.631934     0.477308          -0.555117
# 39005        10.662331         7.458420     0.300489           0.894663
# 39006         1.305636         0.447926     0.656929          -1.415453
# 39007         7.642834         5.541856     0.274895          -0.495395
#
#        Isophotal Area  Sersic Index  Image Index
# 0                  30      0.784617            0
# ...
